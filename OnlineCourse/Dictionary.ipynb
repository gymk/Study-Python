# %%
d = {'key1' : 'value1', 'key2' : 'value2', 'key3':'value3'}

# %%
d
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}

# %%
d['key2']
# Out:
# 'value2'

# %%
d.items()
# Out:
# dict_items([('key1', 'value1'), ('key2', 'value2'), ('key3', 'value3')])

# %%
d
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}

# %%
d['key4'] = 1234

# %%
d
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3', 'key4': 1234}

# %%
d[1234] = 'key5'

# %%
d
# Out:
# {'key1': 'value1',
#  'key2': 'value2',
#  'key3': 'value3',
#  'key4': 1234,
#  1234: 'key5'}

# %%
d[1234]
# Out:
# 'key5'

# %%
d['key4'].bit_length()
# Out:
# 11

# %%
d['key1'].upper()
# Out:
# 'VALUE1'

# %%
d
# Out:
# {'key1': 'value1',
#  'key2': 'value2',
#  'key3': 'value3',
#  'key4': 1234,
#  1234: 'key5'}

# %%
d[1234] += 'ABCD'

# %%
d
# Out:
# {'key1': 'value1',
#  'key2': 'value2',
#  'key3': 'value3',
#  'key4': 1234,
#  1234: 'key5ABCD'}

# %%
d[1.2] = 'float value'

# %%
d
# Out:
# {'key1': 'value1',
#  'key2': 'value2',
#  'key3': 'value3',
#  'key4': 1234,
#  1234: 'key5ABCD',
#  1.2: 'float value'}

# %%
d.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3', 'key4', 1234, 1.2])

# %%
# Using comprehension as iterator with dict keys
[x*x for x in {4:'a', 5:'b'}.keys()]
# Out:
# [16, 25]

# %%
d.values()
# Out:
# dict_values(['value1', 'value2', 'value3', 1234, 'key5ABCD', 'float value'])

# %%
# Using comprehension as iterator with dict values
[2*x for x in {'a':4,'b':5}.values()]
# Out:
# [10, 8]

# %%
d.items()
# Out:
# dict_items([('key1', 'value1'), ('key2', 'value2'), ('key3', 'value3'), ('key4', 1234), (1234, 'key5ABCD'), (1.2, 'float value')])

# %%
d['nets1']= 'nested_val'

# %%
d = { 'nest1' : { 'nest2' : { 'nest3' : 'nested_val'}}}

# %%
d
# Out:
# {'nest1': {'nest2': {'nest3': 'nested_val'}}}

# %%
d.items()
# Out:
# dict_items([('nest1', {'nest2': {'nest3': 'nested_val'}})])

# %%
d['nest1'].items()
# Out:
# dict_items([('nest2', {'nest3': 'nested_val'})])

# %%
d['nest1'].keys()
# Out:
# dict_keys(['nest2'])

# %%
d['nest1'].values()
# Out:
# dict_values([{'nest3': 'nested_val'}])

# %%
d['nest1']['nest2'].values()
# Out:
# dict_values(['nested_val'])

# %%
d['nest1']['nest2']['nest3'].upper()
# Out:
# 'NESTED_VAL'

# %%
d
# Out:
# {'nest1': {'nest2': {'nest3': 'nested_val'}}}

# %%
# for loop over dictionary gives key
d = {'key1' : 'value1', 'key2' : 'value2', 'key3':'value3'}
for val in d:
    print(val)
# Out:
# key1
# key2
# key3

# %%
d = {'Neo': 'Keanu', 'Morpheus':'Laurence','Trinit':'Carrier-Anne'}

# %%
d['Neo']
# Out:
# 'Keanu'

# %%
d['Who']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-ab98bb6f8265> in <module>()
# ----> 1 d['Who']
#
# KeyError: 'Who'

# %%
'Who' in d
# Out:
# False

# %%
# Constructing a dictionary from set using comprehension
{k:v for (k,v) in [(3,2),(4,0),(100,1)]}
# Out:
# {3: 2, 4: 0, 100: 1}

# %%
{(x,y):x*y for x in [1,2,3] for y in [1,2,3]}
# Out:
# {(1, 1): 1,
#  (1, 2): 2,
#  (1, 3): 3,
#  (2, 1): 2,
#  (2, 2): 4,
#  (2, 3): 6,
#  (3, 1): 3,
#  (3, 2): 6,
#  (3, 3): 9}
