# %%
l = (1, 2, 3)

# %%
l
# Out:
# (1, 2, 3)

# %%
l[0]
# Out:
# 1

# %%
l[:2]
# Out:
# (1, 2)

# %%
l.count(2)
# Out:
# 1

# %%
l = l + (4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-9e8ec0011f0e> in <module>()
# ----> 1 l = l + (4)
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
l = (1,'two',3,'four','five,5')

# %%
l
# Out:
# (1, 'two', 3, 'four', 'five,5')

# %%
l = (1,[2,3],(3,4,5))

# %%
l
# Out:
# (1, [2, 3], (3, 4, 5))

# %%
l.count(2)
# Out:
# 0

# %%
l[0]
# Out:
# 1

# %%
l[1]
# Out:
# [2, 3]

# %%
l[2]
# Out:
# (3, 4, 5)

# %%
# tuple unpacking
(a,b) = (2*2,3*4)
print(a,b)
# Out:
# 4 12

# %%
a,b = (3**3,4**4)
print(a,b)
# Out:
# 27 256

# %%
# unpacking using comprehension
[y for (x,y) in [('A',1),('B',2),('C',3)]]
# Out:
# [1, 2, 3]

# %%
# is it possible to convert list to tuple
l = [1,2,3]
t = tuple(l)
t
# Out:
# (1, 2, 3)
